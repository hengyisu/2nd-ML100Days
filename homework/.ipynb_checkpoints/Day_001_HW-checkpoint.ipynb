# %% [markdown]
# 作業1:
# 1.你選的這組資料為何重要?
#
# Heart Disease UCI (URL:https://www.kaggle.com/ronitf/heart-disease-uci/activity)
# 這是一組有關心臟病的資料，裡面有年齡、性別、運動時會不會心絞痛等，這些資料在醫學方面提供我們探討那些因子患有心臟病的可能較高。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 匈牙利心臟病學會。布達佩斯：Andras Janosi，MD
# 瑞士蘇黎世大學醫院：William Steinbrunn，醫學博士
# 瑞士巴塞爾大學醫院：Matthias Pfisterer，醫學博士
# VA醫療中心，長灘和克利夫蘭診所基金會：Robert Detrano，醫學博士，博士
# 捐助者：David W. Aha（aha'@'ics.uci.edu）（714）856-8779
#
# 可能為醫院所提供的資料庫，目前約300筆資料，此資料量相較於台灣健保資料明顯少很多。
# 3. 蒐集而來的資料型態為何
#
# 多為int以及float型態。
#
# 4. 這組資料想解決的問題如何評估
#
# 這組資料收集了一些有關心臟病的因子的數據，透過這些數據可以找到其因子權重比例，有可以進行分析看看哪個男、女生患病比例以及年齡分布，那些數值落在不安全的狀況之下需要特別注意，甚至提前預防。
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 作為一個車隊的領導，首先很清楚的知道要提升業績，也就是載客數愈多生意愈好。假設現在人都用APP叫車，那麼哪個司機到達乘客的時間愈快，則該司機前往以提升效率。而在較多人出沒的地方，例如:車站，根據需求量來動態配置計程車等待的車輛數。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 乘客與司機的位址，map路線狀況→預估到達時間
# 與高、台鐵車站合作，取得對號車該站下車的人數，進行計程車配置，減少司機等待時間過久
# 3. 蒐集而來的資料型態為何
#
# 乘客GPS:
# 司機GPS:
# 到達時間:
# 下車人數:int
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 乘客叫車等車時間↓
# 司機等待時間↓
# 營業額↑
#
#
#
# 作業3：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：ML100 > data資料夾 & homework資料夾 (ipynb檔)
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((abs(y - yp)**2)) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 216.892
# The Mean absolute error is 11.601
